# %%
import numpy as np
import car_class as c
import environment_class as e
import initialiser_functions as i
import tpop as t
import tpop_simulation_functions as tsim

# %%
depth = 2
witness_number_per_depth = [2, 2, 2]
London = e.Environment([0,5], [0,5], 0.25)
threshold = 1
n = 10000
p = 0
q = 0
number_of_simulations = 100

car_list = []
for x in range(n):
    car = i.car_gen(p, q, London)
    car_list.append(car)


e.environment_update(car_list, 0.001, London)
for car in car_list:
    #print(car.coerced)
    tree = t.Tree2(car, depth, witness_number_per_depth)
    output = t.reverse_bfs(tree, witness_number_per_depth, threshold)
True_Positive, True_Negative, False_Positive, False_Negative, True_Positive_cars = t.results(car_list)

print(True_Positive, True_Negative, False_Positive, False_Negative)
#Tpop is depth 2 nw = [2, 2]
# npol is depth 1 nw = all neighbours (or density)
#hard code the number of neighbours of each car for NPoL
# Out:
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 19
#      16 e.environment_update(car_list, 0.001, London)
#      17 for car in car_list:
#      18     #print(car.coerced)
# ---> 19     tree = t.Tree2(car, depth, witness_number_per_depth)
#      20     output = t.reverse_bfs(tree, witness_number_per_depth, threshold)
#      21 True_Positive, True_Negative, False_Positive, False_Negative, True_Positive_cars = t.results(car_list)
#
# File ~/Desktop/T-PoP/tpop.py:60, in Tree2.__init__(self, prover, depth, n)
#      56 for node in self.nodes[d]:
#      57     #the node names some witnesses
#      58     witnesses = node.name_witness(n[d])
# ---> 60     for witness in witnesses:
#      61         #we set the parent of that witness to be the node naming them
#      62         witness.parent = node
#      63         s.append(witness)
#
# TypeError: 'NoneType' object is not iterable

# %% [markdown]
# ## T-PoP with depth 2, threshold 100% and witness_number_per_depth = [2, 2]. 1000 cars in total

# %%
number_of_cars = 100
depth = 2
witness_number_per_depth = [2, 2, 2]
threshold = 1


target_path = '/tpop/t1/'

path = tsim.make_directory(target_path)


simulation_id = 0

f = open("tpop1_simulation_pathfiles.txt", "w+")


for probability_honest in range(0, 110, 10):
    probability_honest = probability_honest/100

    for probability_coerced in range(0, 110, 10):
        
        probability_coerced = probability_coerced/100
    
        number_of_simulations = 100

        simulation_id += 1

        sim_df = tsim.tpop_simulator(number_of_simulations, number_of_cars, probability_honest, probability_coerced, depth, witness_number_per_depth, threshold)

        sim_pathfile = tsim.save_simulation(sim_df, path, str(simulation_id) + 'p_honest' + str(probability_honest*100) + 'p_coerced' + str(probability_coerced*100)) 

        #saving the pathfiles of each simulation in the following text file.
        print('saving sim: ', str(simulation_id) + 'p_honest' + str(probability_honest*100) + 'p_coerced' + str(probability_coerced*100))
        f=open("tpop1_simulation_pathfiles.txt", "a+")
        f.write(sim_pathfile+'\n')
        f.close()
# Out:
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  2 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  2 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  2 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  2 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  2 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  2 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  2 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  2 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  2 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  2 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  2 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  2 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  2 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  2 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  2 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  2 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  2 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  2 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  2 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  2 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# ...
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  2 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  2 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  2 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  2 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  2 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  2 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  2 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  2 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  2 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  0 2
# root counter  1 2
# root counter  0 2
# root counter  1 2
# root counter  1 2
# root counter  0 2
# root counter  0 2
# root counter  None 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 28
#      24 number_of_simulations = 100
#      26 simulation_id += 1
# ---> 28 sim_df = tsim.tpop_simulator(number_of_simulations, number_of_cars, probability_honest, probability_coerced, depth, witness_number_per_depth, threshold)
#      30 sim_pathfile = tsim.save_simulation(sim_df, path, str(simulation_id) + 'p_honest' + str(probability_honest*100) + 'p_coerced' + str(probability_coerced*100))
#      32 #saving the pathfiles of each simulation in the following text file.
#
# File ~/Desktop/T-PoP/tpop_simulation_functions.py:49, in tpop_simulator(number_of_simulations, number_of_cars, probability_of_honest, probability_of_coerced, depth, witness_number_per_depth, threshold)
#      46 for car in car_list:
#      48     tree = t.Tree2(car, depth, witness_number_per_depth)
# ---> 49     output = t.reverse_bfs(tree, witness_number_per_depth, threshold)
#      51 True_Positive, True_Negative, False_Positive, False_Negative, Accuracy = t.results(car_list)
#      52 row = parser(simulation, probability_of_honest, probability_of_coerced, density, threshold, Accuracy, True_Positive, True_Negative, False_Positive, False_Negative)
#
# File ~/Desktop/T-PoP/tpop.py:101, in reverse_bfs(tree, witness_number_per_depth, threshold)
#      99 print('root counter ', root.counter, int(number_of_witnesses_needed * threshold))
#     100 #check that the root has enough approvals to be considered honest
# --> 101 if root.counter >= int(number_of_witnesses_needed * threshold):
#     102     root.algorithm_honesty_output = True
#     103 else:
#
# TypeError: '>=' not supported between instances of 'NoneType' and 'int'

# %% [markdown]
# ## T-PoP with depth 2, threshold 66% and witness_number_per_depth = [3, 3]. 1000 cars in total

# %%
number_of_cars = 1000
depth = 2
witness_number_per_depth = [3, 3]
threshold = 0.66


target_path = '/tpop/t66_n2_d2/'

path = tsim.make_directory(target_path)


simulation_id = 0

f = open("tpop_t66_n2_d2_simulation_pathfiles.txt", "w+")


for probability_lying in range(0, 110, 10):
    probability_lying = probability_lying/100

    for probability_coerced in range(0, 110, 10):
        
        probability_coerced = probability_coerced/100
    
        number_of_simulations = 100

        simulation_id += 1

        sim_df = tsim.tpop_simulator(number_of_simulations, number_of_cars, probability_lying, probability_coerced, depth, witness_number_per_depth, threshold)

        sim_pathfile = tsim.save_simulation(sim_df, path, str(simulation_id) + 'p_lying' + str(probability_lying*100) + 'p_coerced' + str(probability_coerced*100)) 

        #saving the pathfiles of each simulation in the following text file.
        print('saving sim: ', str(simulation_id) + 'p_lying' + str(probability_lying*100) + 'p_coerced' + str(probability_coerced*100))
        f=open("tpop_t66_n2_d2_simulation_pathfiles.txt", "a+")
        f.write(sim_pathfile+'\n')
        f.close()

# %% [markdown]
# ## T-PoP with depth 1, threshold 100% and witness_number_per_depth = [6]. 1000 cars in total

# %%
number_of_cars = 1000
depth = 1
witness_number_per_depth = [6]


target_path = '/tpop/t2n6/'

path = tsim.make_directory(target_path)


simulation_id = 0

f = open("tpop2_simulation_pathfiles.txt", "w+")


for probability_lying in range(0, 110, 10):
    probability_lying = probability_lying/100

    for probability_coerced in range(0, 110, 10):
        
        probability_coerced = probability_coerced/100
    
        number_of_simulations = 100

        simulation_id += 1

        sim_df = tsim.tpop_simulator(number_of_simulations, number_of_cars, probability_lying, probability_coerced, depth, witness_number_per_depth)

        sim_pathfile = tsim.save_simulation(sim_df, path, str(simulation_id) + 'p_lying' + str(probability_lying*100) + 'p_coerced' + str(probability_coerced*100)) 

        #saving the pathfiles of each simulation in the following text file.
        print('saving sim: ', str(simulation_id) + 'p_lying' + str(probability_lying*100) + 'p_coerced' + str(probability_coerced*100))
        f=open("tpop2_simulation_pathfiles.txt", "a+")
        f.write(sim_pathfile+'\n')
        f.close()

# %% [markdown]
# ## T-PoP with depth 1, threshold 66% and witness_number_per_depth = [6]. 1000 cars in total

# %%
number_of_cars = 1000
depth = 1
witness_number_per_depth = [6]
threshold = 0.66

target_path = '/tpop/t66_n6_d1/'

path = tsim.make_directory(target_path)


simulation_id = 0

f = open("tpop_t66_n6_d1_simulation_pathfiles.txt", "w+")


for probability_lying in range(0, 110, 10):
    probability_lying = probability_lying/100

    for probability_coerced in range(0, 110, 10):
        
        probability_coerced = probability_coerced/100
    
        number_of_simulations = 100

        simulation_id += 1

        sim_df = tsim.tpop_simulator(number_of_simulations, number_of_cars, probability_lying, probability_coerced, depth, witness_number_per_depth, threshold)

        sim_pathfile = tsim.save_simulation(sim_df, path, str(simulation_id) + 'p_lying' + str(probability_lying*100) + 'p_coerced' + str(probability_coerced*100)) 

        #saving the pathfiles of each simulation in the following text file.
        print('saving sim: ', str(simulation_id) + 'p_lying' + str(probability_lying*100) + 'p_coerced' + str(probability_coerced*100))
        f=open("tpop_t66_n6_d1_simulation_pathfiles.txt", "a+")
        f.write(sim_pathfile+'\n')
        f.close()

# %%
import matplotlib.pyplot as plt
import pandas as pd

directory_pathfile = "C:\\Users\\aidam\\OneDrive - Imperial College London\\Desktop\\tpop folder\\T-PoP\\tpop\\t1"

# loading dataset
dataset = tsim.full_csv_windows(directory_pathfile)
#print(dataset)
simulations = pd.DataFrame(dataset)


import numpy as np
x = 'Probability of lying cars'
y = 'Probability of coerced cars'
z = 'False Negatives'

df_temp = simulations[[x, y, z]].reset_index(drop=True)
df_temp = df_temp.groupby([x, y]).mean().reset_index()
print(df_temp.sort_values([x, y]))

xlist = df_temp[x].values
ylist = df_temp[y].values
X, Y = np.meshgrid(xlist, ylist)

Z = np.zeros(X.shape)
#for each FP that equals 0, set it to a very small value below 1/1000 
for i in range(X.shape[0]):
    for j in range(X.shape[1]):
        z_val = df_temp[z][
            (df_temp[y] == Y[i, j]) & (df_temp[x] == X[i, j])
        ]
        if z_val.empty:
            Z[i, j] = 0

        else:
            Z[i, j] = z_val
#print(Z)
fig,ax=plt.subplots(1,1)
cp = ax.contourf(X, Y, Z, vmin = 0.000, vmax = 200, cmap='RdGy', levels = 200)
fig.colorbar(cp) # Add a colorbar to a plot
ax.set_title(f'Contour plot of `{z}`')
ax.set_xlabel(x)
ax.set_ylabel(y)
#plt.show()
